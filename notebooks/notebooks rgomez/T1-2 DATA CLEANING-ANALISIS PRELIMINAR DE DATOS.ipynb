# %% [markdown]
# # RESUMEN DE LOS DATOS, DIMENSIONES Y ESTRUCTURAS

# %%
import pandas as pd
import os

# %%
mainPath = "/users/rafael/Documents/GitHub/python-ml-course/datasets"
fileName = "titanic/titanic3.csv"
#fullpath = mainPath + fileName
fullpath = os.path.join(mainPath,fileName)

#Comando para Obtener el directorio donde me encuentro actualmente
#print(os.getcwd())  
#os.getcwd()

#PARA LEER LOS DATOS DIRECTAMENTE DESDE UNA URL
urlData="https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/titanic/titanic3.csv"

# %%
#data=pd.read_csv(fullpath)

data=pd.read_csv(urlData)

# %%
data.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
data.tail(8)
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1301       3         0       Youseff, Mr. Gerious    male  45.5      0      0
# 1302       3         0          Yousif, Mr. Wazli    male   NaN      0      0
# 1303       3         0      Yousseff, Mr. Gerious    male   NaN      0      0
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1301    2628   7.2250   NaN        C  NaN  312.0       NaN
# 1302    2647   7.2250   NaN        C  NaN    NaN       NaN
# 1303    2627  14.4583   NaN        C  NaN    NaN       NaN
# ...

# %%
data.shape
# Out:
# (1309, 14)

# %%
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# HAGAMOS UN RESUMEN DE LOS ESTADISTICOS BASICOS DE LAS VARIABLES NUMERICAS

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
fileName1="rgomez/estadisticas1.csv"
fullpath2=os.path.join(mainPath,fileName1)

# %%
data1=pd.read_csv(fullpath2)

# %%
data1.head(8)
# Out:
#    Numero  2020  2019  2018  2017  2016  2015  2014  2013  2012  ...  2003  \
# 0       1     4    16    10    19    18    15    12    19    17  ...     5
# 1       2     1    13    10    14    15    14    16    14    16  ...     7
# 2       3     0    13     8    19    12     8    14    11     9  ...     6
# 3       4     3    14     6    11    17     9    17    16    18  ...     6
# 4       5     2     9    10    19    18    10     9    15    11  ...     7
# 5       6     3     7     6     6    16    11    17    15    20  ...     5
# 6       7     0    14     4     4    15     8    11    17    17  ...     7
# 7       8     1    20     8    16    17    15    11    13    20  ...     5
#
#    2002  2001  2000  1999  1998  1997  1996  1995  1994
# 0     6     7    14     8    10    12    12     6     0
# 1     3    12     6     4     6     8     9     9     0
# 2     7     9     9     7     3     9     6    12     1
# 3    10     3     5    13     4     9     6    12     2
# ...

# %%
data1.describe()
# Out:
#           Numero       2020       2019       2018       2017       2016  \
# count  45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# mean   23.000000   1.733333  13.866667   7.333333  14.000000  13.866667
# std    13.133926   1.213560   3.388483   2.611165   3.747727   3.684118
# min     1.000000   0.000000   5.000000   2.000000   4.000000   6.000000
# 25%    12.000000   1.000000  12.000000   6.000000  12.000000  12.000000
# 50%    23.000000   2.000000  14.000000   7.000000  14.000000  13.000000
# 75%    34.000000   3.000000  15.000000   9.000000  17.000000  16.000000
# max    45.000000   4.000000  23.000000  13.000000  20.000000  23.000000
#
#             2015       2014       2013       2012  ...       2003       2002  \
# count  45.000000  45.000000  45.000000  45.000000  ...  45.000000  45.000000
# mean   13.866667  14.000000  13.866667  14.000000  ...   6.933333   6.933333
# std     3.552208   3.431141   2.833244   4.279975  ...   2.396968   2.863564
# ...

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object
